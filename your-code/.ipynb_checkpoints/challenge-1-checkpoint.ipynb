# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)
plt.style.use('ggplot')
plt.figure(figsize=(10, 10))

ax1 = plt.subplot(2, 1, 1)
ax1.title.set_text('X Vs Y')
ax1.set_xticklabels([])
ax1.plot(x, y, color='b', linewidth=4)

ax2 = plt.subplot(2, 1, 2)
ax2.title.set_text('X Vs Z')
ax2.plot(x, z, color='g', linewidth=4);

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
plt.style.use('bmh')
fig, ax = plt.subplots(2, figsize=(10,8))

ax[0].title.set_text('X Vs Y')
ax[0].set_xticklabels([])
ax[0].plot(x, y, color='b', linewidth=4)

ax[1].title.set_text('X Vs Z')
ax[1].plot(x, z, color='g', linewidth=4);

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
plt.style.use('bmh')
fig, ax = plt.subplots(2, figsize=(15,10))

# Primera grafica
ax[0].title.set_text('X Vs Y')
ax[0].set_xticklabels([])
ax[0].plot(x, y, color='b', linewidth=4)

# Segunda grafica
ax[1].title.set_text('X Vs Z')
ax[1].plot(x, z, color='g', linewidth=4);

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
plt.style.use('bmh')
fig, ax = plt.subplots(2, figsize=(15,10))

ax[0].title.set_text('X Vs Y')
ax[0].set_xticklabels([])
ax[0].plot(x, y, color='b', linewidth=4)
ax[0].set_ylabel('X*2')

ax[1].title.set_text('X Vs Z')
ax[1].plot(x, z, color='g', linewidth=4)
ax[1].set_ylabel('X**2')
ax[1].set_xlabel('Values');

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here
y = x**2
z = 2.718282**x

# %%
# Normal scale
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(15, 10))

plt.plot(x, y, color='r', linewidth=4)
plt.plot(x, z, color='g', linewidth=4)
plt.title('Normal');

# %%
# Logaritmic Scale
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(15, 10))

plt.plot(x, y, color='r', linewidth=4)
plt.plot(x, z, color='g', linewidth=4)
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_title('Logaritmic');

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
df = pd.read_csv('vehicles.csv')

# %%
x = df['Combined MPG']
y = df['Highway MPG']

plt.figure(figsize=(10, 8))
plt.style.use('seaborn-darkgrid')

plt.scatter(x, y, alpha=0.5, norm=0.5, color='y')
plt.title('Combined MPG Vs Highway MPG', fontsize=25)
plt.ylabel('Highway MPG', fontsize=18)
plt.xlabel('Combined MPG', fontsize=18);

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here
plt.figure(figsize=(10,6))
plt.style.use('seaborn-darkgrid')

plt.boxplot(df['CO2 Emission Grams/Mile'], labels=['CO2 Emission Grams/Mile'], showmeans=True);

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
plt.figure(figsize=(10,6))
plt.hist(df['Fuel Barrels/Year'], bins=60, color='g')
plt.legend(['Fuel Barrels/Year']);

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
df2 = df[['Fuel Type', 'City MPG']].groupby('Fuel Type', as_index=False).mean('City MPG')
x = df2['Fuel Type']
y = df2['City MPG']

# %%
plt.figure(figsize=(10,6))
plt.bar(x, height=y, color='c')

plt.xticks(rotation=90)
plt.xlabel('Fuel Type')
plt.ylabel('City MPG (mean value)')
plt.show();
