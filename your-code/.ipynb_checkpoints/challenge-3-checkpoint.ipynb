# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes(exclude=object)
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
#your code here- categorical variable
titanic.select_dtypes(include=object)
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
plt.figure(figsize=(12,6))
plt.style.use('classic')

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
x = titanic['Age']
plt.hist(x)
plt.xlabel('Age')
plt.ylabel('Number of pleople');

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
fig, age = plt.subplots(ncols=1, nrows=3, figsize=(12, 8))

age[0].title.set_text('10 Bins')
age[0].set_xticklabels([])
age[0].hist(titanic['Age'], bins=10)
age[0].set_ylabel('Number of people')

age[1].title.set_text('20 Bins')
age[1].set_xticklabels([])
age[1].hist(titanic['Age'], bins=20)
age[1].set_ylabel('Number of people')

age[2].title.set_text('50 Bins')
age[2].hist(titanic['Age'], bins=50)
age[2].set_ylabel('Number of people')
age[2].set_xlabel('Age')

plt.show();

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here
#lo afecta porque a mayor cantidad de bins segmenta más los datos y se puede apreciar mejor como se distribuyen
#en cambio con menos bins se agrupan mas los datos y se puede perder de vista variaciones importantes

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (12, 6)})

sns.histplot(titanic['Age'], color='c', kde=True);

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (12, 6)})

sns.histplot(titanic['Gender'], color='c');

# %%
# your code here- 2nd way
titanic_genders = titanic.groupby('Gender',as_index=False).count()
titanic_genders.columns
x = titanic_genders['Gender']
y = titanic_genders['PassengerId']

plt.xlabel('Gender')
plt.ylabel('Count')
plt.bar(x,y, color = 'c');

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
titanic_genders = titanic.groupby('Pclass',as_index=False).count()
titanic_genders.columns
x = titanic_genders['Pclass']
y = titanic_genders['PassengerId']

plt.xlabel('Pclass')
plt.ylabel('Count')
plt.bar(x,y, color = 'c');

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
titanic.Age.describe()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
plt.boxplot(titanic['Age'], labels=['Age']);

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
# your comment here
#la edad media de los pasajeros era de aprozimadamente 29 años
#el 50% de los pasajeros eran adultos jovenes entre los 21 y 38 años
#habían bebes a bordo
#un 25% de los pasajeros eran niños y adolescentes hasta los 21 años.
#otro 25% eran personas de entre 38 y 59 añon, con algunos casos de personas mayores de 60

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
y = titanic['Fare']
x = titanic['Age']

plt.style.use('ggplot')
plt.figure(figsize=(10, 7))
plt.scatter(x=x, y=y, c='r')
plt.ylabel('Fare')
plt.xlabel('Age')

plt.show();

# %%
# your code-2nd way
plt.figure(figsize=(10, 7))
sns.scatterplot(x=x, y=y, color='c');

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
mask = np.zeros_like(titanic.corr(), dtype=bool)
mask[np.triu_indices_from(mask)] = True

plt.subplots(figsize=(10,8))
sns.heatmap(titanic.corr(), mask=mask);

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
# Las columnas mas relacionadas directamente proporcional son: fare-survived y Parch-SibSp
# las columnas mas relacionadas inversamente proporcional son: Fare-Pclass, Age-Pclass y Survived-Pclass

#La tarifa que pagaron (y la clase)tiene relación con haber sobrevivido 
#la relación entre la cantidad de dinero que pagaron los pasajeros tiene que ver con las clase en la que estaban en el barco

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
plt.figure(figsize=(10, 6))
sns.boxplot(x=titanic['Pclass'], y=titanic['Age']);

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
plt.figure(figsize=(10, 6))
sns.boxplot(x=titanic['Gender'], y=titanic['Age']);
