# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes(exclude=['object'])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
#your code here- categorical variable
titanic.select_dtypes(include=['object'])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
plt.style.use('classic')
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
titanic['Age'] = titanic['Age'].astype('int')

# %%
# your code here
plt.hist(titanic['Age'])
# Out:
# (array([ 66.,  65., 296., 372., 226., 140.,  85.,  41.,  15.,   3.]),
#  array([ 0.,  8., 16., 24., 32., 40., 48., 56., 64., 72., 80.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
ax1.hist(titanic['Age'], bins=10)

ax2.hist(titanic['Age'], bins=20)

ax3.hist(titanic['Age'], bins=50)
# Out:
# (array([ 22.,  19.,  10.,  11.,   4.,  19.,   9.,   7.,  24.,   6.,  43.,
#          73.,  27., 107.,  46.,  93., 101.,  38., 111.,  29.,  95.,  48.,
#          34.,  29.,  20.,  45.,  31.,  12.,  36.,  16.,  30.,  25.,   7.,
#          14.,   9.,   9.,   9.,   8.,  11.,   4.,   8.,   2.,   0.,   3.,
#           2.,   0.,   1.,   1.,   0.,   1.]),
#  array([ 0. ,  1.6,  3.2,  4.8,  6.4,  8. ,  9.6, 11.2, 12.8, 14.4, 16. ,
#         17.6, 19.2, 20.8, 22.4, 24. , 25.6, 27.2, 28.8, 30.4, 32. , 33.6,
#         35.2, 36.8, 38.4, 40. , 41.6, 43.2, 44.8, 46.4, 48. , 49.6, 51.2,
#         52.8, 54.4, 56. , 57.6, 59.2, 60.8, 62.4, 64. , 65.6, 67.2, 68.8,
#         70.4, 72. , 73.6, 75.2, 76.8, 78.4, 80. ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here

# More bins make hard to read the different groups of ages

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.histplot(titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
#
#                                                 Name  Gender  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500    U0        S
# 1      0   PC 17599  71.2833   C85        C

# %%
# your code here- 1st way
size = titanic.groupby('Gender', as_index=False).size()
size
# Out:
#    Gender  size
# 0  female   466
# 1    male   843

# %%
# your code here- 2nd way
plt.bar(size['Gender'], size['size'])
# Out:
# <BarContainer object of 2 artists>

# %%
sns.barplot(x=size['Gender'], y=size['size'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='size'>

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
pclass = titanic.groupby('Pclass', as_index=False).size()

# %%
plt.pie(pclass['size'], labels=pclass['Pclass'])
# Out:
# ([<matplotlib.patches.Wedge at 0x2bd1d0c3e20>,
# ...
#  [Text(0.7857105825523255, 0.7698434129518062, '1'),
#   Text(-0.6607894097998425, 0.8794073890389915, '2'),
#   Text(-0.14346972497658556, -1.0906037034666365, '3')])

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
summary = titanic['Age'].describe()
summary
# Out:
# count    1309.000000
# mean       29.747135
# std        13.469166
# min         0.000000
# 25%        22.000000
# 50%        28.000000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
plt.boxplot(titanic['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bd1e469490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2bd1e469b50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2bd1e469130>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bd1e476250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bd1e4765b0>],
#  'means': []}

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here

# The outliers are above the third quartile

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here

plt.hist(titanic['Age'], bins=15)
# Out:
# (array([ 56.,  33.,  42., 192., 233., 243., 186., 104.,  76.,  66.,  34.,
#          26.,  10.,   6.,   2.]),
#  array([ 0.        ,  5.33333333, 10.66666667, 16.        , 21.33333333,
#         26.66666667, 32.        , 37.33333333, 42.66666667, 48.        ,
#         53.33333333, 58.66666667, 64.        , 69.33333333, 74.66666667,
#         80.        ]),
#  <BarContainer object of 15 artists>)

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
# The majority of people were in between the age of 20 and 30

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
plt.scatter(titanic['Age'], titanic['Fare'], s=50)

# %%
# your code-2nd way
sns.scatterplot(titanic['Age'], titanic['Fare'])
# Out:
# C:\Users\c725676\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
plt.subplots(figsize=(20,10))
sns.heatmap(titanic.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here

#Pclass vs Fare

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
sns.boxplot(x=titanic['Pclass'],y=titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
g = sns.FacetGrid(titanic, col='Gender')
g.map(sns.histplot, "Age")
